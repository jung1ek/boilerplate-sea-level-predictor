# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np

# %%
sea_df = pd.read_csv('epa-sea-level.csv')

# %%
print(sea_df.to_string())
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  NOAA Adjusted Sea Level
# 0    1880                  0.000000          -0.952756           0.952756                      NaN
# 1    1881                  0.220472          -0.732283           1.173228                      NaN
# 2    1882                 -0.440945          -1.346457           0.464567                      NaN
# 3    1883                 -0.232283          -1.129921           0.665354                      NaN
# 4    1884                  0.590551          -0.283465           1.464567                      NaN
# 5    1885                  0.531496          -0.330709           1.393701                      NaN
# 6    1886                  0.437008          -0.381890           1.255906                      NaN
# 7    1887                  0.216535          -0.602362           1.035433                      NaN
# ...

# %%
x_label=sea_df['Year']
y_label=sea_df['CSIRO Adjusted Sea Level']

# %%
plt.scatter(x_label,y_label)

# %%
slope, intercept, r, p, se = linregress(x_label, y_label)

# %%
new_x_label = np.arange(1880,2050)

# %%
new_x_label
# Out:
# array([1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890,
#        1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901,
#        1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912,
#        1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923,
#        1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934,
#        1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945,
#        1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#        1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#        1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#        1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
# ...

# %%
plt.scatter(x_label,y_label)
plt.plot(new_x_label,intercept+slope*new_x_label)

# %%
slope, intercept,r,p,se = linregress(df['Year'],df['CSIRO Adjusted Sea Level'])

# %%
x = sea_df[sea_df['Year']>=2000]['Year']
y = sea_df[sea_df['Year']>=2000]['CSIRO Adjusted Sea Level']
# Out:
# 120    2000
# 121    2001
# 122    2002
# 123    2003
# 124    2004
# 125    2005
# 126    2006
# 127    2007
# 128    2008
# 129    2009
# 130    2010
# 131    2011
# 132    2012
# 133    2013
# Name: Year, dtype: int64
